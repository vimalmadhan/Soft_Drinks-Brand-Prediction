# %% [markdown]
# # Import the Necessary Libraries

# %%
import os
import keras
from keras.preprocessing.image import load_img,img_to_array
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np
import pandas as pd
from glob import glob

# %% [markdown]
# # Loading the saved model for prediction

# %%
model = keras.models.load_model('cooldrinks_model.h5')

# %% [markdown]
# # Classes in model

# %%
train_path = '/home/vimalkumar/Documents/cool drinks'
folders = glob('/home/vimalkumar/Documents/cool drinks/*')

keys = []
values = []
for key in range(len(folders)):
    #print(key)
    keys.append(key)
for path in os.listdir(train_path):
    #print(path)
    values.append(path)
dic = dict(list(zip(keys,sorted(values))))
print(dic)
# Out:
# {0: 'Fanta', 1: 'Mazza', 2: 'Sprite', 3: 'coke', 4: 'pepsi'}

# %% [markdown]
# # Prediction code

# %%
def predict_image(path):
    img = image.load_img(path, 
                         target_size=(200,200))
    plt.imshow(img)
    plt.show()

    x = image.img_to_array(img)
    x = x/255
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    val = model.predict(images)
    print(val)

    a=np.argmax(val,axis=1)
    #print(a)
    print('The Brand Name : ',dic[a[0]])

# %% [markdown]
# # Prediction

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/7654-0003.jpeg'
predict_image(path)
# Out:
# [[0.24432456 0.13859554 0.04529088 0.4282288  0.14356026]]
# The Brand Name :  coke

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/images (13).jpeg'
predict_image(path)
# Out:
# [[7.5423095e-04 1.2927912e-03 1.9286989e-04 9.9598807e-01 1.7721022e-03]]
# The Brand Name :  coke

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/photo-1542765426-37a9ce8083a9.jpeg'
predict_image(path)
# Out:
# [[0.00135713 0.01624233 0.00264345 0.7078111  0.27194598]]
# The Brand Name :  coke

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/16f195edd08478f7d447b726ea1df148.jpg'
predict_image(path)
# Out:
# [[2.4232015e-03 2.8163844e-04 9.9701971e-01 3.3193584e-05 2.4226896e-04]]
# The Brand Name :  Sprite

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/519okNpItHL.jpg'
predict_image(path)
# Out:
# [[0.22031252 0.09599317 0.67492676 0.00224793 0.00651961]]
# The Brand Name :  Sprite

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/sprite-bottle-white-background-chisinau-moldova-april-plastic-famous-colorless-lemon-lime-flavored-soft-drink-created-185054039.jpg'
predict_image(path)
# Out:
# [[4.8150177e-04 1.7690923e-05 9.9819559e-01 1.2119589e-03 9.3321796e-05]]
# The Brand Name :  Sprite

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/download.png'
predict_image(path)
# Out:
# [[9.9959618e-01 6.3011030e-05 2.0015967e-04 8.3897772e-05 5.6688656e-05]]
# The Brand Name :  Fanta

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/953aec422f499e7dab9ab3d6489cc1db.jpg'
predict_image(path)
# Out:
# [[9.8936695e-01 1.0517252e-02 4.6792044e-05 1.5209474e-05 5.3761349e-05]]
# The Brand Name :  Fanta

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/images (1).jpeg'
predict_image(path)
# Out:
# [[9.51326728e-01 3.18012536e-02 6.40548812e-03 2.55589857e-05
#   1.04409885e-02]]
# The Brand Name :  Fanta

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/download (1).jpeg'
predict_image(path)
# Out:
# [[7.7494408e-04 9.9615747e-01 5.1811873e-04 2.0213341e-03 5.2808883e-04]]
# The Brand Name :  Mazza

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/download (2).jpeg'
predict_image(path)
# Out:
# [[0.12655716 0.41559038 0.01807006 0.1010427  0.33873966]]
# The Brand Name :  Mazza

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/3bb06288aa5d2443567d4bcfe727839c.webp'
predict_image(path)
# Out:
# [[0.02564636 0.6267645  0.00142612 0.2855627  0.0606004 ]]
# The Brand Name :  Mazza

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/download (4).jpeg'
predict_image(path)
# Out:
# [[1.0926052e-05 3.2258794e-02 2.8459111e-03 4.1209604e-04 9.6447235e-01]]
# The Brand Name :  pepsi

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/Image0001.jpg47d889a6-da0d-414b-95ea-67f438ac5c12Original.jpg'
predict_image(path)
# Out:
# [[1.4981034e-02 1.2558967e-02 6.6117296e-04 2.3382299e-03 9.6946061e-01]]
# The Brand Name :  pepsi

# %%
path = '/home/vimalkumar/Documents/cooldrinks_test/images.jpeg'
predict_image(path)
# Out:
# [[0.1808247  0.00997537 0.00540584 0.21813948 0.58565456]]
# The Brand Name :  pepsi
